# %% [markdown]
# # Automatização de Processos

# %% [markdown]
# ## Problema passo a passo
#
# - Passo 1: buscar informações das ações de forma automática
# - Passo 2: criar as análises dos dados
# - Passo 3: enviar um e-mail para o meu gestor com os resultados das análises

# %% [markdown]
# ## Passo 1: buscar informações das ações de forma automática

# %%
# !pip install yfinance

# %%
import yfinance as yf

# %%
ticker = input("Digite um codigo da ação: ")
dados = yf.Ticker(ticker).history("6mo")
# Out:
# Digite um codigo da ação: BBAS3.SA

# %%
fechamento = dados.Close
print(fechamento)
# Out:
# Date
# 2023-02-09 00:00:00-03:00    37.632416
# 2023-02-10 00:00:00-03:00    38.373848
# 2023-02-13 00:00:00-03:00    38.592472
# 2023-02-14 00:00:00-03:00    39.495499
# 2023-02-15 00:00:00-03:00    39.856712
#                                ...
# 2023-08-03 00:00:00-03:00    47.650002
# 2023-08-04 00:00:00-03:00    47.400002
# 2023-08-07 00:00:00-03:00    47.320000
# 2023-08-08 00:00:00-03:00    46.990002
# 2023-08-09 00:00:00-03:00    46.700001
# Name: Close, Length: 124, dtype: float64

# %%
fechamento
fechamento.plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ## Passo 2: criar as análises dos dados
#
# - cotação máxima
# - cotação mínima
# - cotação atual

# %%
cotacao_maxima = round(fechamento.max(), 2)
cotacao_minima = round(fechamento.min(), 2)
cotacao_atual = round(fechamento[-1], 2)

print(f"A cotação máxima é de: R${cotacao_maxima}")
print(f"A cotação mínima é de: R${cotacao_minima}")
print(f"A cotação atual é de: R${cotacao_atual}")
# Out:
# A cotação máxima é de: R$51.99
# A cotação mínima é de: R$36.29
# A cotação atual é de: R$46.7

# %% [markdown]
# ## Passo 3: enviar um e-mail para o meu gestor com os resultados das análises
#
# - abrir uma nova aba
# - digitar o endereço do GMail, ENTER
# - clicar no botão "Escrever"
# - digitar o destinatário,tab
# - digitar o assunto, tab
# - digitar a mesangem
# - clicar em enviar

# %%
# !pip install pyautogui

# %%
# !pip install pyperclip

# %%
import pyautogui
import pyperclip

# %%
#pause de 2 segundos entre os passos
pyautogui.PAUSE = 5

#abrir uma nova aba (ctrl+t)
pyautogui.hotkey("ctrl", "t")

#digitar o endereço do Gmail, Enter
pyperclip.copy("www.gmail.com")
pyautogui.hotkey("ctrl","v")
pyautogui.hotkey("enter")

#clicar em escrever
pyautogui.click(x=139, y=211)

#digitar o destinatário
pyperclip.copy("giovane_cma@hotmail.com")
pyautogui.hotkey("ctrl", "v")
pyperclip.copy("paula_kologeski@hotmail.com")
pyautogui.hotkey("ctrl", "v")
pyautogui.hotkey("tab")

#digitar o assunto
pyperclip.copy("Relatório das análises de ações")
pyautogui.hotkey("ctrl", "v")
pyautogui.hotkey("tab")

#digitar a mensagem
mensagem = f""" 

Prezado Giovane, 

As análises das recomendações de compra de ações para o mês de Agosto estão disponíveis.

Destaco, também, os dados da empresa {ticker}, que aponta uma grande oporunidade de compra. 

Empresa:{ticker}
Cotação atual: R${cotacao_atual}

Qualquer dúvida, estou à disposição.

Att,

Giovane Seberino.
"""

pyperclip.copy(mensagem)
pyautogui.hotkey("ctrl", "v")

#enviar mensagem
pyautogui.hotkey("ctrl", "enter")
print("Mensagem enviada com sucesso!")
# Out:
# Mensagem enviada com sucesso!
